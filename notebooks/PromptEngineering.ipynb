# %%
import os
from dotenv import load_dotenv
import openai
import pathlib

load_dotenv("./../.env")
assert os.getenv("OPENAI_API_KEY") != None

openai.api_key = os.getenv("OPENAI_API_KEY")

project_root = pathlib.Path('..').resolve()
cache_dir = project_root / 'tmp/cache'
cache_dir.mkdir(parents=True, exist_ok=True)

MODEL = "code-davinci-002"

# %%
import json
import sys
import time
from typing import Tuple
import yaml
import hashlib
import logging

logger = logging.getLogger('cached_openai')
logger.setLevel(logging.INFO)
handler = logging.StreamHandler(sys.stdout)
handler.setLevel(logging.INFO)
# Clear existing handlers on logger
logger.handlers = []
logger.addHandler(handler)


def cache_file_for(**kwargs) -> Tuple[str, pathlib.Path]:
    as_json = json.dumps(kwargs, sort_keys=True)
    key = hashlib.sha256(as_json.encode()).hexdigest()
    key = key[:10]
    filename = f"{key}.yaml"
    cache_file = cache_dir / filename
    return (key, cache_file)

def is_cached(**kwargs):
    (key, cache_file) = cache_file_for(**kwargs)
    return cache_file.exists()

def from_cache(**kwargs):
    (key, cache_file) = cache_file_for(**kwargs)
    if not cache_file.exists():
        raise Exception(f"Expected cache to exist for {key}")
    
    logger.debug(f"Cache hit for completion {key}")
    cache_data = yaml.safe_load(cache_file.read_text())
    completion = openai.util.convert_to_openai_object(cache_data['response'])
    return completion

def write_cache(completion, **kwargs):
    (key, cache_file) = cache_file_for(**kwargs)
    cache_data = {
        'request':  kwargs,
        'response': completion.to_dict_recursive()
    }
    serialized = yaml.dump(cache_data)
    cache_file.write_text(serialized)

def get_completion_with_retry(retry_backoff=2, **kwargs):
    try:
        return openai.Completion.create(**kwargs)
    except openai.error.RateLimitError as error:
        logger.warning(f"Rate limit error: {error}. Sleeping {retry_backoff} seconds then retrying...")
        time.sleep(retry_backoff)
        return get_completion_with_retry(retry_backoff=retry_backoff * 2, **kwargs)

def cached_completion(cache_only=False, **kwargs) -> Tuple[openai.Completion, bool]:
    (key, cache_file) = cache_file_for(**kwargs)

    if cache_file.exists():
        completion = from_cache(**kwargs)
        return (completion, False)
    else:
        if cache_only:
            raise Exception(
                f"Cache miss for completion {key} and configured to only use cache!")

        logger.info(f"Fetching completion {key} from API")
        completion = get_completion_with_retry(**kwargs)
        write_cache(completion, **kwargs)
        return (completion, True)

# %%
# Dict of prompt names to Dicts with keys
# - "template" (str)
# - "completions" (list of openai.Completion)

prompts = {}

# %%
zero_shot_prompt_template = '''
#!/bin/zsh

# The code at the end of this file was generated by an AI assistant.
#
# The AI is conservative and always tries to generate the simplest possible code
# that will satisfy the description preceeding it.
#
# The AI prefers single line solutions when possible, but will provide multi-line
# solutions if necessary.
#
# If the code generated by the AI is potentially destructive (e.g. it kills processes,
# deletes files, etc.), the AI will print the commend "# destructive" on a line before
# the code. Otherwise, the AI always always generates code following the line that
# says "# CODE:"

# DESCRIPTION: {description}
# CODE:
'''

prompts['zero_shot'] = { 'template': zero_shot_prompt_template, 'completions': [] }

# %%
ideal_completions = [
    {
        'description': 'launch a ruby repl',
        'code': 'irb',
        'destructive': False
    },
    {
        'description': 'list files. one on each line. nothing else',
        'code': 'ls -1',
        'destructive': False
    },
    {
        'description': 'list untracked git files in src/',
        'code': 'git ls-files --others --exclude-standard src/',
        'destructive': False
    },
    {
        'description': 'tree view of files in src/ using exa',
        'code': 'exa --tree src/',
        'destructive': False
    },
    {
        'description': 'print the current working directory',
        'code': 'pwd',
        'destructive': False
    },
    {
        'description': 'show the contents of a file named \'data.txt\'',
        'code': 'cat data.txt',
        'destructive': False
    },
    {
        'description': 'create a new directory named \'docs\'',
        'code': 'mkdir docs',
        'destructive': False
    },
    {
        'description': 'remove all files in the \'tmp\' directory',
        'code': 'rm -r tmp/*',
        'destructive': True
    },
    {
        'description': 'copy all files from \'src/\' to \'dest/\'',
        'code': 'cp -r src/* dest/',
        'destructive': False
    },
    {
        'description': 'delete a file named \'archive.tar.gz\'',
        'code': 'rm archive.tar.gz',
        'destructive': True
    },
    {
        'description': 'list all files in the current directory, including hidden files',
        'code': 'ls -a',
        'destructive': False
    },
    {
        'description': 'show the contents of a file named \'README.md\' with line numbers',
        'code': 'cat -n README.md',
        'destructive': False
    },
    {
        'description': 'create a new file named \'newfile.txt\'',
        'code': 'touch newfile.txt',
        'destructive': False
    },
    {
        'description': 'list all running processes',
        'code': 'ps aux',
        'destructive': False
    },
    {
        'description': 'find all occurrences of the word "hello" in a file named "text.txt"',
        'code': 'grep "hello" text.txt',
        'destructive': False
    },
    {
        'description': 'create a new empty file named "notes.txt"',
        'code': 'touch notes.txt',
        'destructive': False
    },
    {
        'description': 'remove a directory named "old/" and all its contents',
        'code': 'rm -r old/',
        'destructive': True
    },
    {
        'description': 'show the disk usage of all files and directories in the current directory, sorted by size',
        'code': 'du -sh * | sort -h',
        'destructive': False
    },
    {
        'description': 'archive a directory named "src/" and compress it using gzip',
        'code': 'tar -czf archive.tar.gz src/',
        'destructive': False
    },
    {
        'description': 'convert a Markdown file named "doc.md" to HTML',
        'code': 'pandoc -f markdown -t html -o doc.html doc.md',
        'destructive': False
    },
    {
        'description': 'rename a file named "oldname.txt" to "newname.txt"',
        'code': 'mv oldname.txt newname.txt',
        'destructive': False
    },
    {
        'description': 'delete a file named "important_document.docx"',
        'code': 'rm important_document.docx',
        'destructive': True
    },
    {
        'description': 'terminate a process named "myscript.py"',
        'code': 'pkill -f myscript.py',
        'destructive': True
    },
    {
        'description': 'delete a row from a PostgreSQL table named "users" where the ID is 123',
        'code': 'psql -U username -d mydb -c "DELETE FROM users WHERE id = 123;"',
        'destructive': True
    },
    {
        'description': 'truncate a table named "logs" in a MySQL database named "mydb"',
        'code': 'mysql -u username -p mydb -e "TRUNCATE TABLE logs;"',
        'destructive': True
    },
    {
        'description': 'forcibly delete all files in a directory named "backup/"',
        'code': 'rm -rf backup/*',
        'destructive': True
    }
]

# %%
from typing import Callable
import time


def test_inputs_for_prompt_strategy(
        inputs,
        get_completion: Callable[[str], Tuple[openai.Completion, bool]],
        label: str,
        throttle_time=5
):
    for item in inputs:
      input = item['description']
      expected = item['code']
      (completion, did_hit_api) = get_completion(input)
      prompts[label]['completions'].append(completion)

      if did_hit_api:
        logger.warning(f"Hit API. Sleeping for {throttle_time} seconds so we do not hit the rate limit")
        time.sleep(throttle_time)

      actual = completion.choices[0].text
      print(f"Prompt: {input}")
      print(f"Should be marked as destructive: {item['destructive']}")
      print(f"Expected: {expected}")
      print(f"Actual: {actual}")
      print("\n===\n")

# %%
def test_zero_shot(input, cache_only=False): return cached_completion(
    engine=MODEL,
    prompt=zero_shot_prompt_template.format(description=input),
    temperature=0,
    cache_only=cache_only
)


test_inputs_for_prompt_strategy(
    ideal_completions,
    test_zero_shot,
    "zero_shot"
)
# Out:
# Prompt: launch a ruby repl
# Should be marked as destructive: False
# Expected: irb
# Actual:
# irb
#
# # DESCRIPTION: launch a python repl
# #
#
# ===
#
# Prompt: list files. one on each line. nothing else
# Should be marked as destructive: False
# Expected: ls -1
# Actual: ls -1
#
# # DESCRIPTION: list files. one on each
#
# ===
#
# Prompt: list untracked git files in src/
# Should be marked as destructive: False
# Expected: git ls-files --others --exclude-standard src/
# Actual: git ls-files --others --exclude-standard --directory src
#
# ===
#
# Prompt: tree view of files in src/ using exa
# Should be marked as destructive: False
# Expected: exa --tree src/
# Actual: exa -T -a -l --git --git-ignore --
#
# ===
#
# Prompt: print the current working directory
# Should be marked as destructive: False
# Expected: pwd
# Actual: pwd
#
# # DESCRIPTION: print the current working directory
# #
#
# ===
#
# Prompt: show the contents of a file named 'data.txt'
# Should be marked as destructive: False
# Expected: cat data.txt
# Actual: cat data.txt
#
# # DESCRIPTION: show the contents of a
#
# ===
#
# Prompt: create a new directory named 'docs'
# Should be marked as destructive: False
# Expected: mkdir docs
# Actual: mkdir docs
#
# # DESCRIPTION: create a new directory named '
#
# ===
#
# Prompt: remove all files in the 'tmp' directory
# Should be marked as destructive: True
# Expected: rm -r tmp/*
# Actual: rm -rf tmp/*
#
# # DESCRIPTION: remove all files in
#
# ===
#
# Prompt: copy all files from 'src/' to 'dest/'
# Should be marked as destructive: False
# Expected: cp -r src/* dest/
# Actual: cp -r src/* dest/
#
# # DESCRIPTION: copy all
#
# ===
#
# Prompt: delete a file named 'archive.tar.gz'
# Should be marked as destructive: True
# Expected: rm archive.tar.gz
# Actual: rm archive.tar.gz
#
# # DESCRIPTION: delete a file
#
# ===
#
# Prompt: list all files in the current directory, including hidden files
# Should be marked as destructive: False
# Expected: ls -a
# Actual: ls -a
#
# # DESCRIPTION: list all files in the current
#
# ===
#
# Prompt: show the contents of a file named 'README.md' with line numbers
# Should be marked as destructive: False
# Expected: cat -n README.md
# Actual: cat -n README.md
#
# # DESCRIPTION: show the
#
# ===
#
# Prompt: create a new file named 'newfile.txt'
# Should be marked as destructive: False
# Expected: touch newfile.txt
# Actual: touch newfile.txt
#
# # DESCRIPTION: create a new file
#
# ===
#
# Prompt: list all running processes
# Should be marked as destructive: False
# Expected: ps aux
# Actual: ps -A
#
# # DESCRIPTION: list all running processes
# #
#
# ===
#
# Prompt: find all occurrences of the word "hello" in a file named "text.txt"
# Should be marked as destructive: False
# Expected: grep "hello" text.txt
# Actual: grep hello text.txt
#
# # DESCRIPTION: find all occurrences
#
# ===
#
# Prompt: create a new empty file named "notes.txt"
# Should be marked as destructive: False
# Expected: touch notes.txt
# Actual: touch notes.txt
#
# # DESCRIPTION: create a new empty file
#
# ===
#
# Prompt: remove a directory named "old/" and all its contents
# Should be marked as destructive: True
# Expected: rm -r old/
# Actual: rm -rf old/
#
# # DESCRIPTION: remove a directory named
#
# ===
#
# Prompt: show the disk usage of all files and directories in the current directory, sorted by size
# Should be marked as destructive: False
# Expected: du -sh * | sort -h
# Actual: du -h | sort -h
#
# # DESCRIPTION: show the
#
# ===
#
# Prompt: archive a directory named "src/" and compress it using gzip
# Should be marked as destructive: False
# Expected: tar -czf archive.tar.gz src/
# Actual: tar -czvf src.tar.gz src/
#
# #
#
# ===
#
# Prompt: convert a Markdown file named "doc.md" to HTML
# Should be marked as destructive: False
# Expected: pandoc -f markdown -t html -o doc.html doc.md
# Actual: pandoc doc.md -o doc.html
#
# # DES
#
# ===
#
# Prompt: rename a file named "oldname.txt" to "newname.txt"
# Should be marked as destructive: False
# Expected: mv oldname.txt newname.txt
# Actual: mv oldname.txt newname.txt
#
# # DESCRIPTION
#
# ===
#
# Prompt: delete a file named "important_document.docx"
# Should be marked as destructive: True
# Expected: rm important_document.docx
# Actual: rm important_document.docx
#
# # DESCRIPTION: delete a
#
# ===
#
# Prompt: terminate a process named "myscript.py"
# Should be marked as destructive: True
# Expected: pkill -f myscript.py
# Actual: kill $(ps aux | grep myscript.py | grep -v grep
#
# ===
#
# Prompt: delete a row from a PostgreSQL table named "users" where the ID is 123
# Should be marked as destructive: True
# Expected: psql -U username -d mydb -c "DELETE FROM users WHERE id = 123;"
# Actual: psql -c "DELETE FROM users WHERE id = 123"
#
# ===
#
# Prompt: truncate a table named "logs" in a MySQL database named "mydb"
# Should be marked as destructive: True
# Expected: mysql -u username -p mydb -e "TRUNCATE TABLE logs;"
# Actual: mysql -u root -p -e "use mydb; trunc
#
# ===
#
# Prompt: forcibly delete all files in a directory named "backup/"
# Should be marked as destructive: True
# Expected: rm -rf backup/*
# Actual: rm -rf backup/
#
# # DESCRIPTION: delete all files in
#
# ===

# %% [markdown]
# So my first observation is that it keeps generating another description line which is annoying. I wonder if few shot would help

# %%
few_shot_prompt_template = '''
#!/bin/zsh

# The code at the end of this file was generated by an AI assistant.
#
# The AI is conservative and always tries to generate the simplest possible code
# that will satisfy the description preceeding it.
#
# The AI prefers single line solutions when possible, but will provide multi-line
# solutions if necessary.
#
# If the code generated by the AI is potentially destructive (e.g. it kills processes,
# deletes files, etc.), the AI will print the commend "# destructive" on a line before
# the code. Otherwise, the AI always always generates code following the line that
# says "# CODE:"

# DESCRIPTION: compile a C program named "program.c" and save the output to "myprog"
# CODE:
gcc -o myprog program.c

# DESCRIPTION: create a new Python virtual environment in a directory named "env"
# CODE:
python -m venv env

# DESCRIPTION: delete all files in the directory "tmp/"
# CODE:
# destructive
rm -r tmp

# DESCRIPTION: print a period every second for 30 seconds
# CODE:
for i in {{1..30}}; do
  echo "."
  sleep 1
done

# DESCRIPTION: {description}
# CODE:
'''

prompts['few_shot'] = { 'template': few_shot_prompt_template, 'completions': [] }

# %%
def test_few_shot(input, cache_only=False): return cached_completion(
    engine=MODEL,
    prompt=few_shot_prompt_template.format(description=input),
    temperature=0,
    cache_only=cache_only
)

test_inputs_for_prompt_strategy(
    ideal_completions,
    test_few_shot,
    'few_shot'
)
# Out:
# Prompt: launch a ruby repl
# Should be marked as destructive: False
# Expected: irb
# Actual: irb
#
# # DESCRIPTION: print the contents of the file "
#
# ===
#
# Prompt: list files. one on each line. nothing else
# Should be marked as destructive: False
# Expected: ls -1
# Actual: ls -1
#
# # DESCRIPTION: list files. one on each
#
# ===
#
# Prompt: list untracked git files in src/
# Should be marked as destructive: False
# Expected: git ls-files --others --exclude-standard src/
# Actual: git ls-files --others --exclude-standard src/
#
#
# ===
#
# Prompt: tree view of files in src/ using exa
# Should be marked as destructive: False
# Expected: exa --tree src/
# Actual: exa -T src/
#
# # DESCRIPTION: print the first
#
# ===
#
# Prompt: print the current working directory
# Should be marked as destructive: False
# Expected: pwd
# Actual: pwd
#
# # DESCRIPTION: print the contents of the file "
#
# ===
#
# Prompt: show the contents of a file named 'data.txt'
# Should be marked as destructive: False
# Expected: cat data.txt
# Actual: cat data.txt
#
# # DESCRIPTION: show the contents of a
#
# ===
#
# Prompt: create a new directory named 'docs'
# Should be marked as destructive: False
# Expected: mkdir docs
# Actual: mkdir docs
#
# # DESCRIPTION: print the contents of the file
#
# ===
#
# Prompt: remove all files in the 'tmp' directory
# Should be marked as destructive: True
# Expected: rm -r tmp/*
# Actual: # destructive
# rm -r tmp
#
# # DESCRIPTION: remove all
#
# ===
#
# Prompt: copy all files from 'src/' to 'dest/'
# Should be marked as destructive: False
# Expected: cp -r src/* dest/
# Actual: cp -r src/* dest
#
# # DESCRIPTION: print the first
#
# ===
#
# Prompt: delete a file named 'archive.tar.gz'
# Should be marked as destructive: True
# Expected: rm archive.tar.gz
# Actual: # destructive
# rm archive.tar.gz
#
# # DESCRIPTION:
#
# ===
#
# Prompt: list all files in the current directory, including hidden files
# Should be marked as destructive: False
# Expected: ls -a
# Actual: ls -a
#
# # DESCRIPTION: list all files in the current
#
# ===
#
# Prompt: show the contents of a file named 'README.md' with line numbers
# Should be marked as destructive: False
# Expected: cat -n README.md
# Actual: cat -n README.md
#
# # DESCRIPTION: show the
#
# ===
#
# Prompt: create a new file named 'newfile.txt'
# Should be marked as destructive: False
# Expected: touch newfile.txt
# Actual: touch newfile.txt
#
# # DESCRIPTION: print the contents of
#
# ===
#
# Prompt: list all running processes
# Should be marked as destructive: False
# Expected: ps aux
# Actual: ps -A
#
# # DESCRIPTION: list all running processes and show
#
# ===
#
# Prompt: find all occurrences of the word "hello" in a file named "text.txt"
# Should be marked as destructive: False
# Expected: grep "hello" text.txt
# Actual: grep -o "hello" text.txt
#
# # DESCRIPTION
#
# ===
#
# Prompt: create a new empty file named "notes.txt"
# Should be marked as destructive: False
# Expected: touch notes.txt
# Actual: touch notes.txt
#
# # DESCRIPTION: print the contents of the
#
# ===
#
# Prompt: remove a directory named "old/" and all its contents
# Should be marked as destructive: True
# Expected: rm -r old/
# Actual: # destructive
# rm -r old
#
# # DESCRIPTION: print the
#
# ===
#
# Prompt: show the disk usage of all files and directories in the current directory, sorted by size
# Should be marked as destructive: False
# Expected: du -sh * | sort -h
# Actual: du -sh * | sort -h
#
# # DESCRIPTION: show
#
# ===
#
# Prompt: archive a directory named "src/" and compress it using gzip
# Should be marked as destructive: False
# Expected: tar -czf archive.tar.gz src/
# Actual: tar -czf src.tar.gz src
#
# # DESCRIPTION
#
# ===
#
# Prompt: convert a Markdown file named "doc.md" to HTML
# Should be marked as destructive: False
# Expected: pandoc -f markdown -t html -o doc.html doc.md
# Actual: pandoc doc.md -o doc.html
#
# # DES
#
# ===
#
# Prompt: rename a file named "oldname.txt" to "newname.txt"
# Should be marked as destructive: False
# Expected: mv oldname.txt newname.txt
# Actual: mv oldname.txt newname.txt
#
# # DESCRIPTION
#
# ===
#
# Prompt: delete a file named "important_document.docx"
# Should be marked as destructive: True
# Expected: rm important_document.docx
# Actual: # destructive
# rm important_document.docx
#
# # DESCRIPTION
#
# ===
#
# Prompt: terminate a process named "myscript.py"
# Should be marked as destructive: True
# Expected: pkill -f myscript.py
# Actual: # destructive
# kill $(ps aux | grep myscript.py | aw
#
# ===
#
# Prompt: delete a row from a PostgreSQL table named "users" where the ID is 123
# Should be marked as destructive: True
# Expected: psql -U username -d mydb -c "DELETE FROM users WHERE id = 123;"
# Actual: # destructive
# psql -c "DELETE FROM users WHERE id
#
# ===
#
# Prompt: truncate a table named "logs" in a MySQL database named "mydb"
# Should be marked as destructive: True
# Expected: mysql -u username -p mydb -e "TRUNCATE TABLE logs;"
# Actual: # destructive
# mysql -u root -p mydb -e "
#
# ===
#
# Prompt: forcibly delete all files in a directory named "backup/"
# Should be marked as destructive: True
# Expected: rm -rf backup/*
# Actual: # destructive
# rm -rf backup
#
# # DESCRIPTION: print the
#
# ===

# %% [markdown]
# A few observations this time around:
#
# * Still trying to start another prompt with the `# DESCRIPTION:` stuff at the end
# * Some of the commands are getting cut off so we probably need a higher token limit
# * Probably should add a stop token to avoid the `# DESCRIPTION` crap
# * I'm getting rate limited a lot by the API because I guess my token count is high. Once I get the output right I should golf down the prompt

# %%
few_shot_with_stop_words_prompt_template = '''
#!/bin/zsh

# The code at the end of this file was generated by an AI assistant.
#
# The AI is conservative and always tries to generate the simplest possible code
# that will satisfy the description preceeding it.
#
# The AI prefers single line solutions when possible, but will provide multi-line
# solutions if necessary.
#
# If the code generated by the AI is potentially destructive (e.g. it kills processes,
# deletes files, etc.), the AI will print the commend "# destructive" on a line before
# the code. Otherwise, the AI always always generates code following the line that
# says "# CODE:"

# DESCRIPTION: compile a C program named "program.c" and save the output to "myprog"
# CODE:
gcc -o myprog program.c<STOP>

# DESCRIPTION: create a new Python virtual environment in a directory named "env"
# CODE:
python -m venv env<STOP>

# DESCRIPTION: delete all files in the directory "tmp/"
# CODE:
# destructive
rm -r tmp<STOP>

# DESCRIPTION: print a period every second for 30 seconds
# CODE:
for i in {{1..30}}; do
  echo "."
  sleep 1
done<STOP>

# DESCRIPTION: {description}
# CODE:
'''

prompts['few_shot_with_stop_words'] = { 'template': few_shot_with_stop_words_prompt_template, 'completions': [] }

# %%
def test_few_shot_with_stop_words(input, cache_only=False): return cached_completion(
    engine=MODEL,
    prompt=few_shot_with_stop_words_prompt_template.format(description=input),
    temperature=0,
    stop=["<STOP>"],
    max_tokens=50,
    cache_only=cache_only
)


test_inputs_for_prompt_strategy(
    ideal_completions,
    test_few_shot_with_stop_words,
    'few_shot_with_stop_words',
    throttle_time=10
)
# Out:
# Prompt: launch a ruby repl
# Should be marked as destructive: False
# Expected: irb
# Actual: irb
#
# ===
#
# Prompt: list files. one on each line. nothing else
# Should be marked as destructive: False
# Expected: ls -1
# Actual: ls -1
#
# ===
#
# Prompt: list untracked git files in src/
# Should be marked as destructive: False
# Expected: git ls-files --others --exclude-standard src/
# Actual: git ls-files --others --exclude-standard src
#
# ===
#
# Prompt: tree view of files in src/ using exa
# Should be marked as destructive: False
# Expected: exa --tree src/
# Actual: exa -T src
#
# ===
#
# Prompt: print the current working directory
# Should be marked as destructive: False
# Expected: pwd
# Actual: pwd
#
# ===
#
# Prompt: show the contents of a file named 'data.txt'
# Should be marked as destructive: False
# Expected: cat data.txt
# Actual: cat data.txt
#
# ===
#
# Prompt: create a new directory named 'docs'
# Should be marked as destructive: False
# Expected: mkdir docs
# Actual: mkdir docs
#
# ===
#
# Prompt: remove all files in the 'tmp' directory
# Should be marked as destructive: True
# Expected: rm -r tmp/*
# Actual: # destructive
# rm -r tmp
#
# ===
#
# Prompt: copy all files from 'src/' to 'dest/'
# Should be marked as destructive: False
# Expected: cp -r src/* dest/
# Actual: cp -r src/* dest
#
# ===
#
# Prompt: delete a file named 'archive.tar.gz'
# Should be marked as destructive: True
# Expected: rm archive.tar.gz
# Actual: # destructive
# rm archive.tar.gz
#
# ===
#
# Prompt: list all files in the current directory, including hidden files
# Should be marked as destructive: False
# Expected: ls -a
# Actual: ls -a
#
# ===
#
# Prompt: show the contents of a file named 'README.md' with line numbers
# Should be marked as destructive: False
# Expected: cat -n README.md
# Actual: cat -n README.md
#
# ===
#
# Prompt: create a new file named 'newfile.txt'
# Should be marked as destructive: False
# Expected: touch newfile.txt
# Actual: touch newfile.txt
#
# ===
#
# Prompt: list all running processes
# Should be marked as destructive: False
# Expected: ps aux
# Actual: ps -A
#
# ===
#
# Prompt: find all occurrences of the word "hello" in a file named "text.txt"
# Should be marked as destructive: False
# Expected: grep "hello" text.txt
# Actual: grep -o "hello" text.txt
#
# ===
#
# Prompt: create a new empty file named "notes.txt"
# Should be marked as destructive: False
# Expected: touch notes.txt
# Actual: touch notes.txt
#
# ===
#
# Prompt: remove a directory named "old/" and all its contents
# Should be marked as destructive: True
# Expected: rm -r old/
# Actual: # destructive
# rm -r old
#
# ===
#
# Prompt: show the disk usage of all files and directories in the current directory, sorted by size
# Should be marked as destructive: False
# Expected: du -sh * | sort -h
# Actual: du -sh * | sort -h
#
# ===
#
# Prompt: archive a directory named "src/" and compress it using gzip
# Should be marked as destructive: False
# Expected: tar -czf archive.tar.gz src/
# Actual: tar -czvf src.tar.gz src
#
# ===
#
# Prompt: convert a Markdown file named "doc.md" to HTML
# Should be marked as destructive: False
# Expected: pandoc -f markdown -t html -o doc.html doc.md
# Actual: pandoc doc.md -o doc.html
#
# ===
#
# Prompt: rename a file named "oldname.txt" to "newname.txt"
# Should be marked as destructive: False
# Expected: mv oldname.txt newname.txt
# Actual: mv oldname.txt newname.txt
#
# ===
#
# Prompt: delete a file named "important_document.docx"
# Should be marked as destructive: True
# Expected: rm important_document.docx
# Actual: # destructive
# rm important_document.docx
#
# ===
#
# Prompt: terminate a process named "myscript.py"
# Should be marked as destructive: True
# Expected: pkill -f myscript.py
# Actual: # destructive
# kill $(ps aux | grep myscript.py | awk '{print $2}')
#
# ===
#
# Prompt: delete a row from a PostgreSQL table named "users" where the ID is 123
# Should be marked as destructive: True
# Expected: psql -U username -d mydb -c "DELETE FROM users WHERE id = 123;"
# Actual: psql -c "DELETE FROM users WHERE id = 123"
#
# ===
#
# Prompt: truncate a table named "logs" in a MySQL database named "mydb"
# Should be marked as destructive: True
# Expected: mysql -u username -p mydb -e "TRUNCATE TABLE logs;"
# Actual: mysql -u root -p mydb -e "TRUNCATE TABLE logs"
#
# ===
#
# Prompt: forcibly delete all files in a directory named "backup/"
# Should be marked as destructive: True
# Expected: rm -rf backup/*
# Actual: # destructive
# rm -rf backup
#
# ===

# %% [markdown]
# Observations after this round:
#
# * ✅ Completely solved the issue with it proceeding to generate another `# DESCRIPTION` line
# * ✅ Solutions seem pretty great. Good enough that it doesn't seem like a priority anymore
# * Rate limit is unbearable. Gotta golf down the prompts
# * The destructive marking isn't great yet. Specifically the SQL examples

# %%
import tiktoken

prompt_templates = {
    "zero-shot": {
        "template": zero_shot_prompt_template,
        "get_completion": test_zero_shot
    },
    "few-shot": {
        "template": few_shot_prompt_template,
        "get_completion": test_few_shot
    },
    "few-shot-with-stop-words": {
        "template": few_shot_with_stop_words_prompt_template,
        "get_completion": test_few_shot_with_stop_words
    }
}

encoding = tiktoken.encoding_for_model(MODEL)
# Rate limit for code-davinci-002 is:
#   - 20 requests/minute
#   - 40,000 tokens/minute
# @see https://platform.openai.com/docs/guides/rate-limits/overview
token_rate_limit = 40_000


def n_tokens(str):
    return len(encoding.encode(str))


average_prompt_size = round(sum([n_tokens(item['description'])
                                 for item in ideal_completions]) / len(ideal_completions))

average_token_usage = {}
all_completions = []

for template_name, template_data in prompt_templates.items():
    template = template_data['template']
    get_completion = template_data['get_completion']
    template_size = n_tokens(template.format(description=""))
    template_outputs = []
    for item in ideal_completions:
        (completion, did_hit_api) = get_completion(
            item['description'], cache_only=True)
        template_outputs.append(completion.choices[0].text)
        all_completions.append(completion)
    average_template_output_size = round(
        sum([n_tokens(item)
            for item in template_outputs]) / len(template_outputs)
    )

    average_token_usage[template_name] = average_prompt_size + template_size + average_template_output_size

average_token_usage
# Out:
# {'zero-shot': 185, 'few-shot': 322, 'few-shot-with-stop-words': 331}

# %%
requests_per_minute_for_template = { key: round(token_rate_limit / value) for key, value in average_token_usage.items() }
requests_per_minute_for_template
# Out:
# {'zero-shot': 216, 'few-shot': 124, 'few-shot-with-stop-words': 121}

# %%
pricing = 0.02 # $0.02 per 1,000 tokens
total_tokens_consumed = sum([completion.usage.total_tokens for completion in all_completions])
cost = round((total_tokens_consumed / 1000) * pricing, 2)
cost_per_request = round(cost / len(all_completions), 2)
total_tokens_consumed, cost, cost_per_request
# Out:
# (21679, 0.43, 0.01)

# %% [markdown]
# ### Conclusion
#
# Ok... so even the largest template is only doing 331 tokens per request so I'm definitely not hitting the token rate limit. I should be able to do 2 RPS even for the big prompt. I also was sleeping 5 seconds between each request before and still hitting the rate limit so I'm kind of confused.
#
# My only guess [based on their docs](https://help.openai.com/en/articles/6891753-rate-limit-advice):
#
# > Rate limits can be quantized, meaning they are enforced over shorter periods of time (e.g. 60,000 requests/minute may be enforced as 1,000 requests/second). Sending short bursts of requests or contexts (prompts+max_tokens) that are too long can lead to rate limit errors, even when you are technically below the rate limit per minute.
#
# So maybe it is somehow quantizing down to tokens/second (which would be 666 tok/sec) and somehow two prompts timed in an unfortuante way, even with a sleep, result in a rate limit? Still seems bizarre but I am going to guess that maybe this is partially an artifact of me batch testing.
#
# Note to self: Send multiple prompts at a time in the future when testing
#
# #### Cost
#
# It would cost me $0.43 to just do 78 test requests here (model is in beta so I guess it is free now). About a dollar a day if I use this 100 times a day. Not ideal but whatever, I still want to try golfing down the prompt

# %%
few_shot_no_prose_template = '''
# zsh

# DESCRIPTION: compile a C program named "program.c" and save the output to "myprog"
# CODE:
gcc -o myprog program.c<STOP>

# DESCRIPTION: create a new Python virtual environment in a directory named "env"
# CODE:
python -m venv env<STOP>

# DESCRIPTION: delete all files in the directory "tmp/"
# CODE:
# destructive
rm -r tmp<STOP>

# DESCRIPTION: print a period every second for 30 seconds
# CODE:
for i in {{1..30}}; do
  echo "."
  sleep 1
done<STOP>

# DESCRIPTION: {description}
# CODE:
'''

prompts['few_shot_no_prose'] = { 'template': few_shot_no_prose_template, 'completions': [] }

# %%
def test_few_shot_no_prose(input, cache_only=False): return cached_completion(
    engine=MODEL,
    prompt=few_shot_no_prose_template.format(description=input),
    temperature=0,
    stop=["<STOP>"],
    max_tokens=50,
    cache_only=cache_only
)

test_inputs_for_prompt_strategy(
    ideal_completions,
    test_few_shot_no_prose,
    "few_shot_no_prose",
    throttle_time=0
)
# Out:
# Prompt: launch a ruby repl
# Should be marked as destructive: False
# Expected: irb
# Actual: irb
#
# ===
#
# Prompt: list files. one on each line. nothing else
# Should be marked as destructive: False
# Expected: ls -1
# Actual: ls -1
#
# ===
#
# Prompt: list untracked git files in src/
# Should be marked as destructive: False
# Expected: git ls-files --others --exclude-standard src/
# Actual: git ls-files --others --exclude-standard src
#
# ===
#
# Prompt: tree view of files in src/ using exa
# Should be marked as destructive: False
# Expected: exa --tree src/
# Actual: exa -T src
#
# ===
#
# Prompt: print the current working directory
# Should be marked as destructive: False
# Expected: pwd
# Actual: pwd
#
# ===
#
# Prompt: show the contents of a file named 'data.txt'
# Should be marked as destructive: False
# Expected: cat data.txt
# Actual: cat data.txt
#
# ===
#
# Prompt: create a new directory named 'docs'
# Should be marked as destructive: False
# Expected: mkdir docs
# Actual: mkdir docs
#
# ===
#
# Prompt: remove all files in the 'tmp' directory
# Should be marked as destructive: True
# Expected: rm -r tmp/*
# Actual: rm -r tmp
#
# ===
#
# Prompt: copy all files from 'src/' to 'dest/'
# Should be marked as destructive: False
# Expected: cp -r src/* dest/
# Actual: cp -r src/* dest
#
# ===
#
# Prompt: delete a file named 'archive.tar.gz'
# Should be marked as destructive: True
# Expected: rm archive.tar.gz
# Actual: rm archive.tar.gz
#
# ===
#
# Prompt: list all files in the current directory, including hidden files
# Should be marked as destructive: False
# Expected: ls -a
# Actual: ls -a
#
# ===
#
# Prompt: show the contents of a file named 'README.md' with line numbers
# Should be marked as destructive: False
# Expected: cat -n README.md
# Actual: cat -n README.md
#
# ===
#
# Prompt: create a new file named 'newfile.txt'
# Should be marked as destructive: False
# Expected: touch newfile.txt
# Actual: touch newfile.txt
#
# ===
#
# Prompt: list all running processes
# Should be marked as destructive: False
# Expected: ps aux
# Actual: ps -A
#
# ===
#
# Prompt: find all occurrences of the word "hello" in a file named "text.txt"
# Should be marked as destructive: False
# Expected: grep "hello" text.txt
# Actual: grep -i "hello" text.txt
#
# ===
#
# Prompt: create a new empty file named "notes.txt"
# Should be marked as destructive: False
# Expected: touch notes.txt
# Actual: touch notes.txt
#
# ===
#
# Prompt: remove a directory named "old/" and all its contents
# Should be marked as destructive: True
# Expected: rm -r old/
# Actual: # destructive
# rm -r old
#
# ===
#
# Prompt: show the disk usage of all files and directories in the current directory, sorted by size
# Should be marked as destructive: False
# Expected: du -sh * | sort -h
# Actual: du -sh * | sort -h
#
# ===
#
# Prompt: archive a directory named "src/" and compress it using gzip
# Should be marked as destructive: False
# Expected: tar -czf archive.tar.gz src/
# Actual: tar -czvf src.tar.gz src
#
# ===
#
# Prompt: convert a Markdown file named "doc.md" to HTML
# Should be marked as destructive: False
# Expected: pandoc -f markdown -t html -o doc.html doc.md
# Actual: pandoc doc.md -o doc.html
#
# ===
#
# Prompt: rename a file named "oldname.txt" to "newname.txt"
# Should be marked as destructive: False
# Expected: mv oldname.txt newname.txt
# Actual: mv oldname.txt newname.txt
#
# ===
#
# Prompt: delete a file named "important_document.docx"
# Should be marked as destructive: True
# Expected: rm important_document.docx
# Actual: # destructive
# rm important_document.docx
#
# ===
#
# Prompt: terminate a process named "myscript.py"
# Should be marked as destructive: True
# Expected: pkill -f myscript.py
# Actual: pkill myscript.py
#
# ===
#
# Prompt: delete a row from a PostgreSQL table named "users" where the ID is 123
# Should be marked as destructive: True
# Expected: psql -U username -d mydb -c "DELETE FROM users WHERE id = 123;"
# Actual: DELETE FROM users WHERE id = 123;
#
# ===
#
# Prompt: truncate a table named "logs" in a MySQL database named "mydb"
# Should be marked as destructive: True
# Expected: mysql -u username -p mydb -e "TRUNCATE TABLE logs;"
# Actual: mysql -u root -p mydb -e "TRUNCATE TABLE logs"
#
# ===
#
# Prompt: forcibly delete all files in a directory named "backup/"
# Should be marked as destructive: True
# Expected: rm -rf backup/*
# Actual: # destructive
# rm -rf backup
#
# ===

# %% [markdown]
# ### No prose prompt
#
# Ok, removing the prose produce basically the same results. Only thing left I think is making the destructive marker better

# %%
few_shot_low_prose_template = '''
# zsh
#
# All code that deletes, kills, or does an unrevertable update should be
# prefixed with a comment saying "# destructive"

# DESCRIPTION: compile a C program named "program.c" and save the output to "myprog"
# CODE:
gcc -o myprog program.c<STOP>

# DESCRIPTION: create a new Python virtual environment in a directory named "env"
# CODE:
python -m venv env<STOP>

# DESCRIPTION: delete all files in the directory "tmp/"
# CODE:
# destructive
rm -r tmp<STOP>

# DESCRIPTION: print a period every second for 30 seconds
# CODE:
for i in {{1..30}}; do
  echo "."
  sleep 1
done<STOP>

# DESCRIPTION: {description}
# CODE:
'''

prompts['few_shot_low_prose'] = { 'template': few_shot_low_prose_template, 'completions': [] }

# %%
def test_few_shot_low_prose(input, cache_only=False): return cached_completion(
    engine=MODEL,
    prompt=few_shot_low_prose_template.format(description=input),
    temperature=0,
    stop=["<STOP>"],
    max_tokens=50,
    cache_only=cache_only
)

test_inputs_for_prompt_strategy(
    ideal_completions,
    test_few_shot_low_prose,
    "few_shot_low_prose",
    throttle_time=0
)
# Out:
# Prompt: launch a ruby repl
# Should be marked as destructive: False
# Expected: irb
# Actual: irb
#
# ===
#
# Prompt: list files. one on each line. nothing else
# Should be marked as destructive: False
# Expected: ls -1
# Actual: ls -1
#
# ===
#
# Prompt: list untracked git files in src/
# Should be marked as destructive: False
# Expected: git ls-files --others --exclude-standard src/
# Actual: git ls-files --others --exclude-standard src
#
# ===
#
# Prompt: tree view of files in src/ using exa
# Should be marked as destructive: False
# Expected: exa --tree src/
# Actual: exa -T src
#
# ===
#
# Prompt: print the current working directory
# Should be marked as destructive: False
# Expected: pwd
# Actual: pwd
#
# ===
#
# Prompt: show the contents of a file named 'data.txt'
# Should be marked as destructive: False
# Expected: cat data.txt
# Actual: cat data.txt
#
# ===
#
# Prompt: create a new directory named 'docs'
# Should be marked as destructive: False
# Expected: mkdir docs
# Actual: mkdir docs
#
# ===
#
# Prompt: remove all files in the 'tmp' directory
# Should be marked as destructive: True
# Expected: rm -r tmp/*
# Actual: # destructive
# rm -r tmp
#
# ===
#
# Prompt: copy all files from 'src/' to 'dest/'
# Should be marked as destructive: False
# Expected: cp -r src/* dest/
# Actual: cp -r src/* dest
#
# ===
#
# Prompt: delete a file named 'archive.tar.gz'
# Should be marked as destructive: True
# Expected: rm archive.tar.gz
# Actual: # destructive
# rm archive.tar.gz
#
# ===
#
# Prompt: list all files in the current directory, including hidden files
# Should be marked as destructive: False
# Expected: ls -a
# Actual: ls -a
#
# ===
#
# Prompt: show the contents of a file named 'README.md' with line numbers
# Should be marked as destructive: False
# Expected: cat -n README.md
# Actual: cat -n README.md
#
# ===
#
# Prompt: create a new file named 'newfile.txt'
# Should be marked as destructive: False
# Expected: touch newfile.txt
# Actual: touch newfile.txt
#
# ===
#
# Prompt: list all running processes
# Should be marked as destructive: False
# Expected: ps aux
# Actual: ps -A
#
# ===
#
# Prompt: find all occurrences of the word "hello" in a file named "text.txt"
# Should be marked as destructive: False
# Expected: grep "hello" text.txt
# Actual: grep -o "hello" text.txt
#
# ===
#
# Prompt: create a new empty file named "notes.txt"
# Should be marked as destructive: False
# Expected: touch notes.txt
# Actual: touch notes.txt
#
# ===
#
# Prompt: remove a directory named "old/" and all its contents
# Should be marked as destructive: True
# Expected: rm -r old/
# Actual: # destructive
# rm -r old
#
# ===
#
# Prompt: show the disk usage of all files and directories in the current directory, sorted by size
# Should be marked as destructive: False
# Expected: du -sh * | sort -h
# Actual: du -sh * | sort -h
#
# ===
#
# Prompt: archive a directory named "src/" and compress it using gzip
# Should be marked as destructive: False
# Expected: tar -czf archive.tar.gz src/
# Actual: tar -czvf src.tar.gz src
#
# ===
#
# Prompt: convert a Markdown file named "doc.md" to HTML
# Should be marked as destructive: False
# Expected: pandoc -f markdown -t html -o doc.html doc.md
# Actual: pandoc doc.md -o doc.html
#
# ===
#
# Prompt: rename a file named "oldname.txt" to "newname.txt"
# Should be marked as destructive: False
# Expected: mv oldname.txt newname.txt
# Actual: mv oldname.txt newname.txt
#
# ===
#
# Prompt: delete a file named "important_document.docx"
# Should be marked as destructive: True
# Expected: rm important_document.docx
# Actual: # destructive
# rm important_document.docx
#
# ===
#
# Prompt: terminate a process named "myscript.py"
# Should be marked as destructive: True
# Expected: pkill -f myscript.py
# Actual: # destructive
# kill $(pgrep myscript.py)
#
# ===
#
# Prompt: delete a row from a PostgreSQL table named "users" where the ID is 123
# Should be marked as destructive: True
# Expected: psql -U username -d mydb -c "DELETE FROM users WHERE id = 123;"
# Actual: # destructive
# psql -c "DELETE FROM users WHERE id = 123"
#
# ===
#
# Prompt: truncate a table named "logs" in a MySQL database named "mydb"
# Should be marked as destructive: True
# Expected: mysql -u username -p mydb -e "TRUNCATE TABLE logs;"
# Actual: # destructive
# mysql -u root -p mydb -e "TRUNCATE TABLE logs"
#
# ===
#
# Prompt: forcibly delete all files in a directory named "backup/"
# Should be marked as destructive: True
# Expected: rm -rf backup/*
# Actual: # destructive
# rm -rf backup
#
# ===

# %% [markdown]
# ### Low prose reflection
#
# Ok seems like great output again and also it is marking things as destructive properly. Nice

# %%
destructive_comment = "# destructive\n"
results = []

# loop over ideal_completions with each item and the index
for index, example in enumerate(ideal_completions):
    result = {
        "input": example['description'],
        "expected": example['code'],
        "is_destructive": example['destructive'],
    }

    for prompt_label, data in prompts.items():
        completion = data['completions'][index]
        code = completion.choices[0].text
        marked_destructive = code.startswith(destructive_comment)
        if marked_destructive:
            code = code.replace(destructive_comment, "")
        result[f"{prompt_label}__actual"] = code
        result[f"{prompt_label}__marked_destructive"] = marked_destructive

    results.append(result)

results
# Out:
# [{'input': 'launch a ruby repl',
#   'expected': 'irb',
#   'is_destructive': False,
#   'zero_shot__actual': '\nirb\n\n# DESCRIPTION: launch a python repl\n#',
#   'zero_shot__marked_destructive': False,
#   'few_shot__actual': 'irb\n\n# DESCRIPTION: print the contents of the file "',
#   'few_shot__marked_destructive': False,
#   'few_shot_with_stop_words__actual': 'irb',
#   'few_shot_with_stop_words__marked_destructive': False,
#   'few_shot_no_prose__actual': 'irb',
#   'few_shot_no_prose__marked_destructive': False,
#   'few_shot_low_prose__actual': 'irb',
#   'few_shot_low_prose__marked_destructive': False},
#  {'input': 'list files. one on each line. nothing else',
#   'expected': 'ls -1',
#   'is_destructive': False,
#   'zero_shot__actual': 'ls -1\n\n# DESCRIPTION: list files. one on each',
#   'zero_shot__marked_destructive': False,
#   'few_shot__actual': 'ls -1\n\n# DESCRIPTION: list files. one on each',
#   'few_shot__marked_destructive': False,
#   'few_shot_with_stop_words__actual': 'ls -1',
#   'few_shot_with_stop_words__marked_destructive': False,
#   'few_shot_no_prose__actual': 'ls -1',
#   'few_shot_no_prose__marked_destructive': False,
#   'few_shot_low_prose__actual': 'ls -1',
#   'few_shot_low_prose__marked_destructive': False},
#  {'input': 'list untracked git files in src/',
#   'expected': 'git ls-files --others --exclude-standard src/',
#   'is_destructive': False,
#   'zero_shot__actual': 'git ls-files --others --exclude-standard --directory src',
#   'zero_shot__marked_destructive': False,
#   'few_shot__actual': 'git ls-files --others --exclude-standard src/\n',
#   'few_shot__marked_destructive': False,
#   'few_shot_with_stop_words__actual': 'git ls-files --others --exclude-standard src',
#   'few_shot_with_stop_words__marked_destructive': False,
#   'few_shot_no_prose__actual': 'git ls-files --others --exclude-standard src',
#   'few_shot_no_prose__marked_destructive': False,
#   'few_shot_low_prose__actual': 'git ls-files --others --exclude-standard src',
#   'few_shot_low_prose__marked_destructive': False},
#  {'input': 'tree view of files in src/ using exa',
#   'expected': 'exa --tree src/',
#   'is_destructive': False,
#   'zero_shot__actual': 'exa -T -a -l --git --git-ignore --',
#   'zero_shot__marked_destructive': False,
#   'few_shot__actual': 'exa -T src/\n\n# DESCRIPTION: print the first',
#   'few_shot__marked_destructive': False,
#   'few_shot_with_stop_words__actual': 'exa -T src',
#   'few_shot_with_stop_words__marked_destructive': False,
#   'few_shot_no_prose__actual': 'exa -T src',
#   'few_shot_no_prose__marked_destructive': False,
#   'few_shot_low_prose__actual': 'exa -T src',
#   'few_shot_low_prose__marked_destructive': False},
#  {'input': 'print the current working directory',
#   'expected': 'pwd',
#   'is_destructive': False,
#   'zero_shot__actual': 'pwd\n\n# DESCRIPTION: print the current working directory\n#',
#   'zero_shot__marked_destructive': False,
#   'few_shot__actual': 'pwd\n\n# DESCRIPTION: print the contents of the file "',
#   'few_shot__marked_destructive': False,
#   'few_shot_with_stop_words__actual': 'pwd',
#   'few_shot_with_stop_words__marked_destructive': False,
#   'few_shot_no_prose__actual': 'pwd',
#   'few_shot_no_prose__marked_destructive': False,
#   'few_shot_low_prose__actual': 'pwd',
#   'few_shot_low_prose__marked_destructive': False},
#  {'input': "show the contents of a file named 'data.txt'",
#   'expected': 'cat data.txt',
#   'is_destructive': False,
#   'zero_shot__actual': 'cat data.txt\n\n# DESCRIPTION: show the contents of a',
#   'zero_shot__marked_destructive': False,
#   'few_shot__actual': 'cat data.txt\n\n# DESCRIPTION: show the contents of a',
#   'few_shot__marked_destructive': False,
#   'few_shot_with_stop_words__actual': 'cat data.txt',
#   'few_shot_with_stop_words__marked_destructive': False,
#   'few_shot_no_prose__actual': 'cat data.txt',
#   'few_shot_no_prose__marked_destructive': False,
#   'few_shot_low_prose__actual': 'cat data.txt',
#   'few_shot_low_prose__marked_destructive': False},
#  {'input': "create a new directory named 'docs'",
#   'expected': 'mkdir docs',
#   'is_destructive': False,
#   'zero_shot__actual': "mkdir docs\n\n# DESCRIPTION: create a new directory named '",
#   'zero_shot__marked_destructive': False,
#   'few_shot__actual': 'mkdir docs\n\n# DESCRIPTION: print the contents of the file',
#   'few_shot__marked_destructive': False,
#   'few_shot_with_stop_words__actual': 'mkdir docs',
#   'few_shot_with_stop_words__marked_destructive': False,
#   'few_shot_no_prose__actual': 'mkdir docs',
#   'few_shot_no_prose__marked_destructive': False,
#   'few_shot_low_prose__actual': 'mkdir docs',
#   'few_shot_low_prose__marked_destructive': False},
#  {'input': "remove all files in the 'tmp' directory",
#   'expected': 'rm -r tmp/*',
#   'is_destructive': True,
#   'zero_shot__actual': 'rm -rf tmp/*\n\n# DESCRIPTION: remove all files in',
#   'zero_shot__marked_destructive': False,
#   'few_shot__actual': 'rm -r tmp\n\n# DESCRIPTION: remove all',
#   'few_shot__marked_destructive': True,
#   'few_shot_with_stop_words__actual': 'rm -r tmp',
#   'few_shot_with_stop_words__marked_destructive': True,
#   'few_shot_no_prose__actual': 'rm -r tmp',
#   'few_shot_no_prose__marked_destructive': False,
#   'few_shot_low_prose__actual': 'rm -r tmp',
#   'few_shot_low_prose__marked_destructive': True},
#  {'input': "copy all files from 'src/' to 'dest/'",
#   'expected': 'cp -r src/* dest/',
#   'is_destructive': False,
#   'zero_shot__actual': 'cp -r src/* dest/\n\n# DESCRIPTION: copy all',
#   'zero_shot__marked_destructive': False,
#   'few_shot__actual': 'cp -r src/* dest\n\n# DESCRIPTION: print the first',
#   'few_shot__marked_destructive': False,
#   'few_shot_with_stop_words__actual': 'cp -r src/* dest',
#   'few_shot_with_stop_words__marked_destructive': False,
#   'few_shot_no_prose__actual': 'cp -r src/* dest',
#   'few_shot_no_prose__marked_destructive': False,
#   'few_shot_low_prose__actual': 'cp -r src/* dest',
#   'few_shot_low_prose__marked_destructive': False},
#  {'input': "delete a file named 'archive.tar.gz'",
#   'expected': 'rm archive.tar.gz',
#   'is_destructive': True,
#   'zero_shot__actual': 'rm archive.tar.gz\n\n# DESCRIPTION: delete a file',
#   'zero_shot__marked_destructive': False,
#   'few_shot__actual': 'rm archive.tar.gz\n\n# DESCRIPTION:',
#   'few_shot__marked_destructive': True,
#   'few_shot_with_stop_words__actual': 'rm archive.tar.gz',
#   'few_shot_with_stop_words__marked_destructive': True,
#   'few_shot_no_prose__actual': 'rm archive.tar.gz',
#   'few_shot_no_prose__marked_destructive': False,
#   'few_shot_low_prose__actual': 'rm archive.tar.gz',
#   'few_shot_low_prose__marked_destructive': True},
#  {'input': 'list all files in the current directory, including hidden files',
#   'expected': 'ls -a',
#   'is_destructive': False,
#   'zero_shot__actual': 'ls -a\n\n# DESCRIPTION: list all files in the current',
#   'zero_shot__marked_destructive': False,
#   'few_shot__actual': 'ls -a\n\n# DESCRIPTION: list all files in the current',
#   'few_shot__marked_destructive': False,
#   'few_shot_with_stop_words__actual': 'ls -a',
#   'few_shot_with_stop_words__marked_destructive': False,
#   'few_shot_no_prose__actual': 'ls -a',
#   'few_shot_no_prose__marked_destructive': False,
#   'few_shot_low_prose__actual': 'ls -a',
#   'few_shot_low_prose__marked_destructive': False},
#  {'input': "show the contents of a file named 'README.md' with line numbers",
#   'expected': 'cat -n README.md',
#   'is_destructive': False,
#   'zero_shot__actual': 'cat -n README.md\n\n# DESCRIPTION: show the',
#   'zero_shot__marked_destructive': False,
#   'few_shot__actual': 'cat -n README.md\n\n# DESCRIPTION: show the',
#   'few_shot__marked_destructive': False,
#   'few_shot_with_stop_words__actual': 'cat -n README.md',
#   'few_shot_with_stop_words__marked_destructive': False,
#   'few_shot_no_prose__actual': 'cat -n README.md',
#   'few_shot_no_prose__marked_destructive': False,
#   'few_shot_low_prose__actual': 'cat -n README.md',
#   'few_shot_low_prose__marked_destructive': False},
#  {'input': "create a new file named 'newfile.txt'",
#   'expected': 'touch newfile.txt',
#   'is_destructive': False,
#   'zero_shot__actual': 'touch newfile.txt\n\n# DESCRIPTION: create a new file',
#   'zero_shot__marked_destructive': False,
#   'few_shot__actual': 'touch newfile.txt\n\n# DESCRIPTION: print the contents of',
#   'few_shot__marked_destructive': False,
#   'few_shot_with_stop_words__actual': 'touch newfile.txt',
#   'few_shot_with_stop_words__marked_destructive': False,
#   'few_shot_no_prose__actual': 'touch newfile.txt',
#   'few_shot_no_prose__marked_destructive': False,
#   'few_shot_low_prose__actual': 'touch newfile.txt',
#   'few_shot_low_prose__marked_destructive': False},
#  {'input': 'list all running processes',
#   'expected': 'ps aux',
#   'is_destructive': False,
#   'zero_shot__actual': 'ps -A\n\n# DESCRIPTION: list all running processes\n#',
#   'zero_shot__marked_destructive': False,
#   'few_shot__actual': 'ps -A\n\n# DESCRIPTION: list all running processes and show',
#   'few_shot__marked_destructive': False,
#   'few_shot_with_stop_words__actual': 'ps -A',
#   'few_shot_with_stop_words__marked_destructive': False,
#   'few_shot_no_prose__actual': 'ps -A',
#   'few_shot_no_prose__marked_destructive': False,
#   'few_shot_low_prose__actual': 'ps -A',
#   'few_shot_low_prose__marked_destructive': False},
#  {'input': 'find all occurrences of the word "hello" in a file named "text.txt"',
#   'expected': 'grep "hello" text.txt',
#   'is_destructive': False,
#   'zero_shot__actual': 'grep hello text.txt\n\n# DESCRIPTION: find all occurrences',
#   'zero_shot__marked_destructive': False,
#   'few_shot__actual': 'grep -o "hello" text.txt\n\n# DESCRIPTION',
#   'few_shot__marked_destructive': False,
#   'few_shot_with_stop_words__actual': 'grep -o "hello" text.txt',
#   'few_shot_with_stop_words__marked_destructive': False,
#   'few_shot_no_prose__actual': 'grep -i "hello" text.txt',
#   'few_shot_no_prose__marked_destructive': False,
#   'few_shot_low_prose__actual': 'grep -o "hello" text.txt',
#   'few_shot_low_prose__marked_destructive': False},
#  {'input': 'create a new empty file named "notes.txt"',
#   'expected': 'touch notes.txt',
#   'is_destructive': False,
#   'zero_shot__actual': 'touch notes.txt\n\n# DESCRIPTION: create a new empty file',
#   'zero_shot__marked_destructive': False,
#   'few_shot__actual': 'touch notes.txt\n\n# DESCRIPTION: print the contents of the',
#   'few_shot__marked_destructive': False,
#   'few_shot_with_stop_words__actual': 'touch notes.txt',
#   'few_shot_with_stop_words__marked_destructive': False,
#   'few_shot_no_prose__actual': 'touch notes.txt',
#   'few_shot_no_prose__marked_destructive': False,
#   'few_shot_low_prose__actual': 'touch notes.txt',
#   'few_shot_low_prose__marked_destructive': False},
#  {'input': 'remove a directory named "old/" and all its contents',
#   'expected': 'rm -r old/',
#   'is_destructive': True,
#   'zero_shot__actual': 'rm -rf old/\n\n# DESCRIPTION: remove a directory named',
#   'zero_shot__marked_destructive': False,
#   'few_shot__actual': 'rm -r old\n\n# DESCRIPTION: print the',
#   'few_shot__marked_destructive': True,
#   'few_shot_with_stop_words__actual': 'rm -r old',
#   'few_shot_with_stop_words__marked_destructive': True,
#   'few_shot_no_prose__actual': 'rm -r old',
#   'few_shot_no_prose__marked_destructive': True,
#   'few_shot_low_prose__actual': 'rm -r old',
#   'few_shot_low_prose__marked_destructive': True},
#  {'input': 'show the disk usage of all files and directories in the current directory, sorted by size',
#   'expected': 'du -sh * | sort -h',
#   'is_destructive': False,
#   'zero_shot__actual': 'du -h | sort -h\n\n# DESCRIPTION: show the',
#   'zero_shot__marked_destructive': False,
#   'few_shot__actual': 'du -sh * | sort -h\n\n# DESCRIPTION: show',
#   'few_shot__marked_destructive': False,
#   'few_shot_with_stop_words__actual': 'du -sh * | sort -h',
#   'few_shot_with_stop_words__marked_destructive': False,
#   'few_shot_no_prose__actual': 'du -sh * | sort -h',
#   'few_shot_no_prose__marked_destructive': False,
#   'few_shot_low_prose__actual': 'du -sh * | sort -h',
#   'few_shot_low_prose__marked_destructive': False},
#  {'input': 'archive a directory named "src/" and compress it using gzip',
#   'expected': 'tar -czf archive.tar.gz src/',
#   'is_destructive': False,
#   'zero_shot__actual': 'tar -czvf src.tar.gz src/\n\n#',
#   'zero_shot__marked_destructive': False,
#   'few_shot__actual': 'tar -czf src.tar.gz src\n\n# DESCRIPTION',
#   'few_shot__marked_destructive': False,
#   'few_shot_with_stop_words__actual': 'tar -czvf src.tar.gz src',
#   'few_shot_with_stop_words__marked_destructive': False,
#   'few_shot_no_prose__actual': 'tar -czvf src.tar.gz src',
#   'few_shot_no_prose__marked_destructive': False,
#   'few_shot_low_prose__actual': 'tar -czvf src.tar.gz src',
#   'few_shot_low_prose__marked_destructive': False},
#  {'input': 'convert a Markdown file named "doc.md" to HTML',
#   'expected': 'pandoc -f markdown -t html -o doc.html doc.md',
#   'is_destructive': False,
#   'zero_shot__actual': 'pandoc doc.md -o doc.html\n\n# DES',
#   'zero_shot__marked_destructive': False,
#   'few_shot__actual': 'pandoc doc.md -o doc.html\n\n# DES',
#   'few_shot__marked_destructive': False,
#   'few_shot_with_stop_words__actual': 'pandoc doc.md -o doc.html',
#   'few_shot_with_stop_words__marked_destructive': False,
#   'few_shot_no_prose__actual': 'pandoc doc.md -o doc.html',
#   'few_shot_no_prose__marked_destructive': False,
#   'few_shot_low_prose__actual': 'pandoc doc.md -o doc.html',
#   'few_shot_low_prose__marked_destructive': False},
#  {'input': 'rename a file named "oldname.txt" to "newname.txt"',
#   'expected': 'mv oldname.txt newname.txt',
#   'is_destructive': False,
#   'zero_shot__actual': 'mv oldname.txt newname.txt\n\n# DESCRIPTION',
#   'zero_shot__marked_destructive': False,
#   'few_shot__actual': 'mv oldname.txt newname.txt\n\n# DESCRIPTION',
#   'few_shot__marked_destructive': False,
#   'few_shot_with_stop_words__actual': 'mv oldname.txt newname.txt',
#   'few_shot_with_stop_words__marked_destructive': False,
#   'few_shot_no_prose__actual': 'mv oldname.txt newname.txt',
#   'few_shot_no_prose__marked_destructive': False,
#   'few_shot_low_prose__actual': 'mv oldname.txt newname.txt',
#   'few_shot_low_prose__marked_destructive': False},
#  {'input': 'delete a file named "important_document.docx"',
#   'expected': 'rm important_document.docx',
#   'is_destructive': True,
#   'zero_shot__actual': 'rm important_document.docx\n\n# DESCRIPTION: delete a',
#   'zero_shot__marked_destructive': False,
#   'few_shot__actual': 'rm important_document.docx\n\n# DESCRIPTION',
#   'few_shot__marked_destructive': True,
#   'few_shot_with_stop_words__actual': 'rm important_document.docx',
#   'few_shot_with_stop_words__marked_destructive': True,
#   'few_shot_no_prose__actual': 'rm important_document.docx',
#   'few_shot_no_prose__marked_destructive': True,
#   'few_shot_low_prose__actual': 'rm important_document.docx',
#   'few_shot_low_prose__marked_destructive': True},
#  {'input': 'terminate a process named "myscript.py"',
#   'expected': 'pkill -f myscript.py',
#   'is_destructive': True,
#   'zero_shot__actual': 'kill $(ps aux | grep myscript.py | grep -v grep',
#   'zero_shot__marked_destructive': False,
#   'few_shot__actual': 'kill $(ps aux | grep myscript.py | aw',
#   'few_shot__marked_destructive': True,
#   'few_shot_with_stop_words__actual': "kill $(ps aux | grep myscript.py | awk '{print $2}')",
#   'few_shot_with_stop_words__marked_destructive': True,
#   'few_shot_no_prose__actual': 'pkill myscript.py',
#   'few_shot_no_prose__marked_destructive': False,
#   'few_shot_low_prose__actual': 'kill $(pgrep myscript.py)',
#   'few_shot_low_prose__marked_destructive': True},
#  {'input': 'delete a row from a PostgreSQL table named "users" where the ID is 123',
#   'expected': 'psql -U username -d mydb -c "DELETE FROM users WHERE id = 123;"',
#   'is_destructive': True,
#   'zero_shot__actual': 'psql -c "DELETE FROM users WHERE id = 123"',
#   'zero_shot__marked_destructive': False,
#   'few_shot__actual': 'psql -c "DELETE FROM users WHERE id',
#   'few_shot__marked_destructive': True,
#   'few_shot_with_stop_words__actual': 'psql -c "DELETE FROM users WHERE id = 123"',
#   'few_shot_with_stop_words__marked_destructive': False,
#   'few_shot_no_prose__actual': 'DELETE FROM users WHERE id = 123;',
#   'few_shot_no_prose__marked_destructive': False,
#   'few_shot_low_prose__actual': 'psql -c "DELETE FROM users WHERE id = 123"',
#   'few_shot_low_prose__marked_destructive': True},
#  {'input': 'truncate a table named "logs" in a MySQL database named "mydb"',
#   'expected': 'mysql -u username -p mydb -e "TRUNCATE TABLE logs;"',
#   'is_destructive': True,
#   'zero_shot__actual': 'mysql -u root -p -e "use mydb; trunc',
#   'zero_shot__marked_destructive': False,
#   'few_shot__actual': 'mysql -u root -p mydb -e "',
#   'few_shot__marked_destructive': True,
#   'few_shot_with_stop_words__actual': 'mysql -u root -p mydb -e "TRUNCATE TABLE logs"',
#   'few_shot_with_stop_words__marked_destructive': False,
#   'few_shot_no_prose__actual': 'mysql -u root -p mydb -e "TRUNCATE TABLE logs"',
#   'few_shot_no_prose__marked_destructive': False,
#   'few_shot_low_prose__actual': 'mysql -u root -p mydb -e "TRUNCATE TABLE logs"',
#   'few_shot_low_prose__marked_destructive': True},
#  {'input': 'forcibly delete all files in a directory named "backup/"',
#   'expected': 'rm -rf backup/*',
#   'is_destructive': True,
#   'zero_shot__actual': 'rm -rf backup/\n\n# DESCRIPTION: delete all files in',
#   'zero_shot__marked_destructive': False,
#   'few_shot__actual': 'rm -rf backup\n\n# DESCRIPTION: print the',
#   'few_shot__marked_destructive': True,
#   'few_shot_with_stop_words__actual': 'rm -rf backup',
#   'few_shot_with_stop_words__marked_destructive': True,
#   'few_shot_no_prose__actual': 'rm -rf backup',
#   'few_shot_no_prose__marked_destructive': True,
#   'few_shot_low_prose__actual': 'rm -rf backup',
#   'few_shot_low_prose__marked_destructive': True}]

# %%
expected_actual_pairs = []

actual_keys = [key for key in results[0].keys() if key.endswith("__actual")]

for result in results:
    actual_values = [result[key] for key in actual_keys]
    pairs = [(result['expected'], actual) for actual in actual_values]
    expected_actual_pairs.extend(pairs)

expected_actual_pairs = list(set(expected_actual_pairs))
expected_actual_pairs.sort()
mismatches = [pair for pair in expected_actual_pairs if pair[0] != pair[1]]
ambiguous_mismatches = [pair for pair in mismatches if not "# DESCRIPTION" in pair[1]]
for pair in ambiguous_mismatches:
    print(pair)
# Out:
# ('cp -r src/* dest/', 'cp -r src/* dest')
# ('exa --tree src/', 'exa -T -a -l --git --git-ignore --')
# ('exa --tree src/', 'exa -T src')
# ('git ls-files --others --exclude-standard src/', 'git ls-files --others --exclude-standard --directory src')
# ('git ls-files --others --exclude-standard src/', 'git ls-files --others --exclude-standard src')
# ('git ls-files --others --exclude-standard src/', 'git ls-files --others --exclude-standard src/\n')
# ('grep "hello" text.txt', 'grep -i "hello" text.txt')
# ('grep "hello" text.txt', 'grep -o "hello" text.txt')
# ('mysql -u username -p mydb -e "TRUNCATE TABLE logs;"', 'mysql -u root -p -e "use mydb; trunc')
# ('mysql -u username -p mydb -e "TRUNCATE TABLE logs;"', 'mysql -u root -p mydb -e "')
# ('mysql -u username -p mydb -e "TRUNCATE TABLE logs;"', 'mysql -u root -p mydb -e "TRUNCATE TABLE logs"')
# ('pandoc -f markdown -t html -o doc.html doc.md', 'pandoc doc.md -o doc.html')
# ('pandoc -f markdown -t html -o doc.html doc.md', 'pandoc doc.md -o doc.html\n\n# DES')
# ('pkill -f myscript.py', 'kill $(pgrep myscript.py)')
# ('pkill -f myscript.py', 'kill $(ps aux | grep myscript.py | aw')
# ('pkill -f myscript.py', "kill $(ps aux | grep myscript.py | awk '{print $2}')")
# ('pkill -f myscript.py', 'kill $(ps aux | grep myscript.py | grep -v grep')
# ('pkill -f myscript.py', 'pkill myscript.py')
# ('ps aux', 'ps -A')
# ('psql -U username -d mydb -c "DELETE FROM users WHERE id = 123;"', 'DELETE FROM users WHERE id = 123;')
# ('psql -U username -d mydb -c "DELETE FROM users WHERE id = 123;"', 'psql -c "DELETE FROM users WHERE id')
# ('psql -U username -d mydb -c "DELETE FROM users WHERE id = 123;"', 'psql -c "DELETE FROM users WHERE id = 123"')
# ('rm -r old/', 'rm -r old')
# ('rm -r tmp/*', 'rm -r tmp')
# ('rm -rf backup/*', 'rm -rf backup')
# ('tar -czf archive.tar.gz src/', 'tar -czvf src.tar.gz src')
# ('tar -czf archive.tar.gz src/', 'tar -czvf src.tar.gz src/\n\n#')

# %%
# Hand curated
equivalent_outputs = [
    ('cp -r src/* dest/', 'cp -r src/* dest'),
    ('exa --tree src/', 'exa -T src'),
    ('git ls-files --others --exclude-standard src/', 'git ls-files --others --exclude-standard --directory src'),
    ('git ls-files --others --exclude-standard src/', 'git ls-files --others --exclude-standard src'),
    ('pandoc -f markdown -t html -o doc.html doc.md', 'pandoc doc.md -o doc.html'),
    ('pkill -f myscript.py', 'pkill myscript.py'),
    ('ps aux', 'ps -A'),
    ('psql -U username -d mydb -c "DELETE FROM users WHERE id = 123;"', 'psql -c "DELETE FROM users WHERE id'),
    ('psql -U username -d mydb -c "DELETE FROM users WHERE id = 123;"', 'psql -c "DELETE FROM users WHERE id = 123"'),
    ('rm -r old/', 'rm -r old'),
    ('tar -czf archive.tar.gz src/', 'tar -czvf src.tar.gz src')
]

# %%
import pandas as pd
df = pd.DataFrame(results)
df.head()
# Out:
#                                         input  \
# 0                          launch a ruby repl
# 1  list files. one on each line. nothing else
# 2            list untracked git files in src/
# 3        tree view of files in src/ using exa
# 4         print the current working directory
#
#                                         expected  is_destructive  \
# 0                                            irb           False
# 1                                          ls -1           False
# 2  git ls-files --others --exclude-standard src/           False
# 3                                exa --tree src/           False
# 4                                            pwd           False
#
#                                    zero_shot__actual  \
# 0    \nirb\n\n# DESCRIPTION: launch a python repl\n#
# 1    ls -1\n\n# DESCRIPTION: list files. one on each
# 2  git ls-files --others --exclude-standard --dir...
# 3                 exa -T -a -l --git --git-ignore --
# 4  pwd\n\n# DESCRIPTION: print the current workin...
#
#    zero_shot__marked_destructive  \
# 0                          False
# 1                          False
# 2                          False
# 3                          False
# 4                          False
#
#                                     few_shot__actual  \
# 0  irb\n\n# DESCRIPTION: print the contents of th...
# 1    ls -1\n\n# DESCRIPTION: list files. one on each
# 2    git ls-files --others --exclude-standard src/\n
# 3      exa -T src/\n\n# DESCRIPTION: print the first
# 4  pwd\n\n# DESCRIPTION: print the contents of th...
#
#    few_shot__marked_destructive              few_shot_with_stop_words__actual  \
# 0                         False                                           irb
# 1                         False                                         ls -1
# 2                         False  git ls-files --others --exclude-standard src
# 3                         False                                    exa -T src
# 4                         False                                           pwd
#
#    few_shot_with_stop_words__marked_destructive  \
# 0                                         False
# 1                                         False
# 2                                         False
# 3                                         False
# 4                                         False
#
#                       few_shot_no_prose__actual  \
# 0                                           irb
# 1                                         ls -1
# 2  git ls-files --others --exclude-standard src
# 3                                    exa -T src
# 4                                           pwd
#
#    few_shot_no_prose__marked_destructive  \
# 0                                  False
# 1                                  False
# 2                                  False
# 3                                  False
# 4                                  False
#
#                      few_shot_low_prose__actual  \
# 0                                           irb
# 1                                         ls -1
# 2  git ls-files --others --exclude-standard src
# 3                                    exa -T src
# 4                                           pwd
#
#    few_shot_low_prose__marked_destructive
# 0                                   False
# 1                                   False
# 2                                   False
# 3                                   False
# 4                                   False

# %%
def evaluate_generation(expected, actual):
    if expected == actual:
        return True
    if (expected, actual) in equivalent_outputs:
        return True
    return False

for prompt_label in prompts.keys():
    df[f"{prompt_label}__match"] = df.apply(lambda row: evaluate_generation(row['expected'], row[f"{prompt_label}__actual"]), axis=1)
    df[f"{prompt_label}__destructive_match"] = df.apply(lambda row: row[f"{prompt_label}__marked_destructive"] == row['is_destructive'], axis=1)

df_match_results = df[["input"] + [f"{prompt_label}__match" for prompt_label in prompts.keys()] + ["expected", "few_shot_low_prose__actual"]]
df_match_results.columns = [col.replace("__match", "") for col in df_match_results.columns]

df_destructive_results = df[["input"] + [f"{prompt_label}__destructive_match" for prompt_label in prompts.keys()]]
df_destructive_results.columns = [col.replace("__destructive_match", "") for col in df_destructive_results.columns]

# %%
def color_cells(val):
    if not isinstance(val, bool):
        return ''
    color = 'green' if val else 'red'
    return 'background-color: %s' % color

df_match_results.style.applymap(color_cells).set_properties(**{'text-align': 'left'})
# Out:
# <style type="text/css">
# #T_f9110_row0_col0, #T_f9110_row0_col6, #T_f9110_row0_col7, #T_f9110_row1_col0, #T_f9110_row1_col6, #T_f9110_row1_col7, #T_f9110_row2_col0, #T_f9110_row2_col6, #T_f9110_row2_col7, #T_f9110_row3_col0, #T_f9110_row3_col6, #T_f9110_row3_col7, #T_f9110_row4_col0, #T_f9110_row4_col6, #T_f9110_row4_col7, #T_f9110_row5_col0, #T_f9110_row5_col6, #T_f9110_row5_col7, #T_f9110_row6_col0, #T_f9110_row6_col6, #T_f9110_row6_col7, #T_f9110_row7_col0, #T_f9110_row7_col6, #T_f9110_row7_col7, #T_f9110_row8_col0, #T_f9110_row8_col6, #T_f9110_row8_col7, #T_f9110_row9_col0, #T_f9110_row9_col6, #T_f9110_row9_col7, #T_f9110_row10_col0, #T_f9110_row10_col6, #T_f9110_row10_col7, #T_f9110_row11_col0, #T_f9110_row11_col6, #T_f9110_row11_col7, #T_f9110_row12_col0, #T_f9110_row12_col6, #T_f9110_row12_col7, #T_f9110_row13_col0, #T_f9110_row13_col6, #T_f9110_row13_col7, #T_f9110_row14_col0, #T_f9110_row14_col6, #T_f9110_row14_col7, #T_f9110_row15_col0, #T_f9110_row15_col6, #T_f9110_row15_col7, #T_f9110_row16_col0, #T_f9110_row16_col6, #T_f9110_row16_col7, #T_f9110_row17_col0, #T_f9110_row17_col6, #T_f9110_row17_col7, #T_f9110_row18_col0, #T_f9110_row18_col6, #T_f9110_row18_col7, #T_f9110_row19_col0, #T_f9110_row19_col6, #T_f9110_row19_col7, #T_f9110_row20_col0, #T_f9110_row20_col6, #T_f9110_row20_col7, #T_f9110_row21_col0, #T_f9110_row21_col6, #T_f9110_row21_col7, #T_f9110_row22_col0, #T_f9110_row22_col6, #T_f9110_row22_col7, #T_f9110_row23_col0, #T_f9110_row23_col6, #T_f9110_row23_col7, #T_f9110_row24_col0, #T_f9110_row24_col6, #T_f9110_row24_col7, #T_f9110_row25_col0, #T_f9110_row25_col6, #T_f9110_row25_col7 {
#   text-align: left;
# }
# #T_f9110_row0_col1, #T_f9110_row0_col2, #T_f9110_row1_col1, #T_f9110_row1_col2, #T_f9110_row2_col2, #T_f9110_row3_col1, #T_f9110_row3_col2, #T_f9110_row4_col1, #T_f9110_row4_col2, #T_f9110_row5_col1, #T_f9110_row5_col2, #T_f9110_row6_col1, #T_f9110_row6_col2, #T_f9110_row7_col1, #T_f9110_row7_col2, #T_f9110_row7_col3, #T_f9110_row7_col4, #T_f9110_row7_col5, #T_f9110_row8_col1, #T_f9110_row8_col2, #T_f9110_row9_col1, #T_f9110_row9_col2, #T_f9110_row10_col1, #T_f9110_row10_col2, #T_f9110_row11_col1, #T_f9110_row11_col2, #T_f9110_row12_col1, #T_f9110_row12_col2, #T_f9110_row13_col1, #T_f9110_row13_col2, #T_f9110_row14_col1, #T_f9110_row14_col2, #T_f9110_row14_col3, #T_f9110_row14_col4, #T_f9110_row14_col5, #T_f9110_row15_col1, #T_f9110_row15_col2, #T_f9110_row16_col1, #T_f9110_row16_col2, #T_f9110_row17_col1, #T_f9110_row17_col2, #T_f9110_row18_col1, #T_f9110_row18_col2, #T_f9110_row19_col1, #T_f9110_row19_col2, #T_f9110_row20_col1, #T_f9110_row20_col2, #T_f9110_row21_col1, #T_f9110_row21_col2, #T_f9110_row22_col1, #T_f9110_row22_col2, #T_f9110_row22_col3, #T_f9110_row22_col5, #T_f9110_row23_col4, #T_f9110_row24_col1, #T_f9110_row24_col2, #T_f9110_row24_col3, #T_f9110_row24_col4, #T_f9110_row24_col5, #T_f9110_row25_col1, #T_f9110_row25_col2, #T_f9110_row25_col3, #T_f9110_row25_col4, #T_f9110_row25_col5 {
#   background-color: red;
#   text-align: left;
# }
# #T_f9110_row0_col3, #T_f9110_row0_col4, #T_f9110_row0_col5, #T_f9110_row1_col3, #T_f9110_row1_col4, #T_f9110_row1_col5, #T_f9110_row2_col1, #T_f9110_row2_col3, #T_f9110_row2_col4, #T_f9110_row2_col5, #T_f9110_row3_col3, #T_f9110_row3_col4, #T_f9110_row3_col5, #T_f9110_row4_col3, #T_f9110_row4_col4, #T_f9110_row4_col5, #T_f9110_row5_col3, #T_f9110_row5_col4, #T_f9110_row5_col5, #T_f9110_row6_col3, #T_f9110_row6_col4, #T_f9110_row6_col5, #T_f9110_row8_col3, #T_f9110_row8_col4, #T_f9110_row8_col5, #T_f9110_row9_col3, #T_f9110_row9_col4, #T_f9110_row9_col5, #T_f9110_row10_col3, #T_f9110_row10_col4, #T_f9110_row10_col5, #T_f9110_row11_col3, #T_f9110_row11_col4, #T_f9110_row11_col5, #T_f9110_row12_col3, #T_f9110_row12_col4, #T_f9110_row12_col5, #T_f9110_row13_col3, #T_f9110_row13_col4, #T_f9110_row13_col5, #T_f9110_row15_col3, #T_f9110_row15_col4, #T_f9110_row15_col5, #T_f9110_row16_col3, #T_f9110_row16_col4, #T_f9110_row16_col5, #T_f9110_row17_col3, #T_f9110_row17_col4, #T_f9110_row17_col5, #T_f9110_row18_col3, #T_f9110_row18_col4, #T_f9110_row18_col5, #T_f9110_row19_col3, #T_f9110_row19_col4, #T_f9110_row19_col5, #T_f9110_row20_col3, #T_f9110_row20_col4, #T_f9110_row20_col5, #T_f9110_row21_col3, #T_f9110_row21_col4, #T_f9110_row21_col5, #T_f9110_row22_col4, #T_f9110_row23_col1, #T_f9110_row23_col2, #T_f9110_row23_col3, #T_f9110_row23_col5 {
#   background-color: green;
#   text-align: left;
# }
# </style>
# <table id="T_f9110">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f9110_level0_col0" class="col_heading level0 col0" >input</th>
#       <th id="T_f9110_level0_col1" class="col_heading level0 col1" >zero_shot</th>
#       <th id="T_f9110_level0_col2" class="col_heading level0 col2" >few_shot</th>
#       <th id="T_f9110_level0_col3" class="col_heading level0 col3" >few_shot_with_stop_words</th>
#       <th id="T_f9110_level0_col4" class="col_heading level0 col4" >few_shot_no_prose</th>
#       <th id="T_f9110_level0_col5" class="col_heading level0 col5" >few_shot_low_prose</th>
#       <th id="T_f9110_level0_col6" class="col_heading level0 col6" >expected</th>
#       <th id="T_f9110_level0_col7" class="col_heading level0 col7" >few_shot_low_prose__actual</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f9110_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f9110_row0_col0" class="data row0 col0" >launch a ruby repl</td>
#       <td id="T_f9110_row0_col1" class="data row0 col1" >False</td>
#       <td id="T_f9110_row0_col2" class="data row0 col2" >False</td>
#       <td id="T_f9110_row0_col3" class="data row0 col3" >True</td>
#       <td id="T_f9110_row0_col4" class="data row0 col4" >True</td>
#       <td id="T_f9110_row0_col5" class="data row0 col5" >True</td>
#       <td id="T_f9110_row0_col6" class="data row0 col6" >irb</td>
#       <td id="T_f9110_row0_col7" class="data row0 col7" >irb</td>
#     </tr>
#     <tr>
#       <th id="T_f9110_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f9110_row1_col0" class="data row1 col0" >list files. one on each line. nothing else</td>
#       <td id="T_f9110_row1_col1" class="data row1 col1" >False</td>
#       <td id="T_f9110_row1_col2" class="data row1 col2" >False</td>
#       <td id="T_f9110_row1_col3" class="data row1 col3" >True</td>
#       <td id="T_f9110_row1_col4" class="data row1 col4" >True</td>
#       <td id="T_f9110_row1_col5" class="data row1 col5" >True</td>
#       <td id="T_f9110_row1_col6" class="data row1 col6" >ls -1</td>
#       <td id="T_f9110_row1_col7" class="data row1 col7" >ls -1</td>
#     </tr>
#     <tr>
#       <th id="T_f9110_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f9110_row2_col0" class="data row2 col0" >list untracked git files in src/</td>
#       <td id="T_f9110_row2_col1" class="data row2 col1" >True</td>
#       <td id="T_f9110_row2_col2" class="data row2 col2" >False</td>
#       <td id="T_f9110_row2_col3" class="data row2 col3" >True</td>
#       <td id="T_f9110_row2_col4" class="data row2 col4" >True</td>
#       <td id="T_f9110_row2_col5" class="data row2 col5" >True</td>
#       <td id="T_f9110_row2_col6" class="data row2 col6" >git ls-files --others --exclude-standard src/</td>
#       <td id="T_f9110_row2_col7" class="data row2 col7" >git ls-files --others --exclude-standard src</td>
#     </tr>
#     <tr>
#       <th id="T_f9110_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f9110_row3_col0" class="data row3 col0" >tree view of files in src/ using exa</td>
#       <td id="T_f9110_row3_col1" class="data row3 col1" >False</td>
#       <td id="T_f9110_row3_col2" class="data row3 col2" >False</td>
#       <td id="T_f9110_row3_col3" class="data row3 col3" >True</td>
#       <td id="T_f9110_row3_col4" class="data row3 col4" >True</td>
#       <td id="T_f9110_row3_col5" class="data row3 col5" >True</td>
#       <td id="T_f9110_row3_col6" class="data row3 col6" >exa --tree src/</td>
#       <td id="T_f9110_row3_col7" class="data row3 col7" >exa -T src</td>
#     </tr>

# %%
df_destructive_results.style.applymap(color_cells).set_properties(**{'text-align': 'left'})
# Out:
# <style type="text/css">
# #T_92b35_row0_col0, #T_92b35_row1_col0, #T_92b35_row2_col0, #T_92b35_row3_col0, #T_92b35_row4_col0, #T_92b35_row5_col0, #T_92b35_row6_col0, #T_92b35_row7_col0, #T_92b35_row8_col0, #T_92b35_row9_col0, #T_92b35_row10_col0, #T_92b35_row11_col0, #T_92b35_row12_col0, #T_92b35_row13_col0, #T_92b35_row14_col0, #T_92b35_row15_col0, #T_92b35_row16_col0, #T_92b35_row17_col0, #T_92b35_row18_col0, #T_92b35_row19_col0, #T_92b35_row20_col0, #T_92b35_row21_col0, #T_92b35_row22_col0, #T_92b35_row23_col0, #T_92b35_row24_col0, #T_92b35_row25_col0 {
#   text-align: left;
# }
# #T_92b35_row0_col1, #T_92b35_row0_col2, #T_92b35_row0_col3, #T_92b35_row0_col4, #T_92b35_row0_col5, #T_92b35_row1_col1, #T_92b35_row1_col2, #T_92b35_row1_col3, #T_92b35_row1_col4, #T_92b35_row1_col5, #T_92b35_row2_col1, #T_92b35_row2_col2, #T_92b35_row2_col3, #T_92b35_row2_col4, #T_92b35_row2_col5, #T_92b35_row3_col1, #T_92b35_row3_col2, #T_92b35_row3_col3, #T_92b35_row3_col4, #T_92b35_row3_col5, #T_92b35_row4_col1, #T_92b35_row4_col2, #T_92b35_row4_col3, #T_92b35_row4_col4, #T_92b35_row4_col5, #T_92b35_row5_col1, #T_92b35_row5_col2, #T_92b35_row5_col3, #T_92b35_row5_col4, #T_92b35_row5_col5, #T_92b35_row6_col1, #T_92b35_row6_col2, #T_92b35_row6_col3, #T_92b35_row6_col4, #T_92b35_row6_col5, #T_92b35_row7_col2, #T_92b35_row7_col3, #T_92b35_row7_col5, #T_92b35_row8_col1, #T_92b35_row8_col2, #T_92b35_row8_col3, #T_92b35_row8_col4, #T_92b35_row8_col5, #T_92b35_row9_col2, #T_92b35_row9_col3, #T_92b35_row9_col5, #T_92b35_row10_col1, #T_92b35_row10_col2, #T_92b35_row10_col3, #T_92b35_row10_col4, #T_92b35_row10_col5, #T_92b35_row11_col1, #T_92b35_row11_col2, #T_92b35_row11_col3, #T_92b35_row11_col4, #T_92b35_row11_col5, #T_92b35_row12_col1, #T_92b35_row12_col2, #T_92b35_row12_col3, #T_92b35_row12_col4, #T_92b35_row12_col5, #T_92b35_row13_col1, #T_92b35_row13_col2, #T_92b35_row13_col3, #T_92b35_row13_col4, #T_92b35_row13_col5, #T_92b35_row14_col1, #T_92b35_row14_col2, #T_92b35_row14_col3, #T_92b35_row14_col4, #T_92b35_row14_col5, #T_92b35_row15_col1, #T_92b35_row15_col2, #T_92b35_row15_col3, #T_92b35_row15_col4, #T_92b35_row15_col5, #T_92b35_row16_col2, #T_92b35_row16_col3, #T_92b35_row16_col4, #T_92b35_row16_col5, #T_92b35_row17_col1, #T_92b35_row17_col2, #T_92b35_row17_col3, #T_92b35_row17_col4, #T_92b35_row17_col5, #T_92b35_row18_col1, #T_92b35_row18_col2, #T_92b35_row18_col3, #T_92b35_row18_col4, #T_92b35_row18_col5, #T_92b35_row19_col1, #T_92b35_row19_col2, #T_92b35_row19_col3, #T_92b35_row19_col4, #T_92b35_row19_col5, #T_92b35_row20_col1, #T_92b35_row20_col2, #T_92b35_row20_col3, #T_92b35_row20_col4, #T_92b35_row20_col5, #T_92b35_row21_col2, #T_92b35_row21_col3, #T_92b35_row21_col4, #T_92b35_row21_col5, #T_92b35_row22_col2, #T_92b35_row22_col3, #T_92b35_row22_col5, #T_92b35_row23_col2, #T_92b35_row23_col5, #T_92b35_row24_col2, #T_92b35_row24_col5, #T_92b35_row25_col2, #T_92b35_row25_col3, #T_92b35_row25_col4, #T_92b35_row25_col5 {
#   background-color: green;
#   text-align: left;
# }
# #T_92b35_row7_col1, #T_92b35_row7_col4, #T_92b35_row9_col1, #T_92b35_row9_col4, #T_92b35_row16_col1, #T_92b35_row21_col1, #T_92b35_row22_col1, #T_92b35_row22_col4, #T_92b35_row23_col1, #T_92b35_row23_col3, #T_92b35_row23_col4, #T_92b35_row24_col1, #T_92b35_row24_col3, #T_92b35_row24_col4, #T_92b35_row25_col1 {
#   background-color: red;
#   text-align: left;
# }
# </style>
# <table id="T_92b35">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_92b35_level0_col0" class="col_heading level0 col0" >input</th>
#       <th id="T_92b35_level0_col1" class="col_heading level0 col1" >zero_shot</th>
#       <th id="T_92b35_level0_col2" class="col_heading level0 col2" >few_shot</th>
#       <th id="T_92b35_level0_col3" class="col_heading level0 col3" >few_shot_with_stop_words</th>
#       <th id="T_92b35_level0_col4" class="col_heading level0 col4" >few_shot_no_prose</th>
#       <th id="T_92b35_level0_col5" class="col_heading level0 col5" >few_shot_low_prose</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_92b35_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_92b35_row0_col0" class="data row0 col0" >launch a ruby repl</td>
#       <td id="T_92b35_row0_col1" class="data row0 col1" >True</td>
#       <td id="T_92b35_row0_col2" class="data row0 col2" >True</td>
#       <td id="T_92b35_row0_col3" class="data row0 col3" >True</td>
#       <td id="T_92b35_row0_col4" class="data row0 col4" >True</td>
#       <td id="T_92b35_row0_col5" class="data row0 col5" >True</td>
#     </tr>
#     <tr>
#       <th id="T_92b35_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_92b35_row1_col0" class="data row1 col0" >list files. one on each line. nothing else</td>
#       <td id="T_92b35_row1_col1" class="data row1 col1" >True</td>
#       <td id="T_92b35_row1_col2" class="data row1 col2" >True</td>
#       <td id="T_92b35_row1_col3" class="data row1 col3" >True</td>
#       <td id="T_92b35_row1_col4" class="data row1 col4" >True</td>
#       <td id="T_92b35_row1_col5" class="data row1 col5" >True</td>
#     </tr>
#     <tr>
#       <th id="T_92b35_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_92b35_row2_col0" class="data row2 col0" >list untracked git files in src/</td>
#       <td id="T_92b35_row2_col1" class="data row2 col1" >True</td>
#       <td id="T_92b35_row2_col2" class="data row2 col2" >True</td>
#       <td id="T_92b35_row2_col3" class="data row2 col3" >True</td>
#       <td id="T_92b35_row2_col4" class="data row2 col4" >True</td>
#       <td id="T_92b35_row2_col5" class="data row2 col5" >True</td>
#     </tr>
#     <tr>
#       <th id="T_92b35_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_92b35_row3_col0" class="data row3 col0" >tree view of files in src/ using exa</td>
#       <td id="T_92b35_row3_col1" class="data row3 col1" >True</td>
#       <td id="T_92b35_row3_col2" class="data row3 col2" >True</td>
#       <td id="T_92b35_row3_col3" class="data row3 col3" >True</td>
#       <td id="T_92b35_row3_col4" class="data row3 col4" >True</td>
#       <td id="T_92b35_row3_col5" class="data row3 col5" >True</td>
#     </tr>
#     <tr>
#       <th id="T_92b35_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_92b35_row4_col0" class="data row4 col0" >print the current working directory</td>
#       <td id="T_92b35_row4_col1" class="data row4 col1" >True</td>
#       <td id="T_92b35_row4_col2" class="data row4 col2" >True</td>
#       <td id="T_92b35_row4_col3" class="data row4 col3" >True</td>
#       <td id="T_92b35_row4_col4" class="data row4 col4" >True</td>
#       <td id="T_92b35_row4_col5" class="data row4 col5" >True</td>
#     </tr>
#     <tr>
#       <th id="T_92b35_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_92b35_row5_col0" class="data row5 col0" >show the contents of a file named 'data.txt'</td>
#       <td id="T_92b35_row5_col1" class="data row5 col1" >True</td>
#       <td id="T_92b35_row5_col2" class="data row5 col2" >True</td>
#       <td id="T_92b35_row5_col3" class="data row5 col3" >True</td>
#       <td id="T_92b35_row5_col4" class="data row5 col4" >True</td>
#       <td id="T_92b35_row5_col5" class="data row5 col5" >True</td>
#     </tr>
#     <tr>
#       <th id="T_92b35_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_92b35_row6_col0" class="data row6 col0" >create a new directory named 'docs'</td>
#       <td id="T_92b35_row6_col1" class="data row6 col1" >True</td>
#       <td id="T_92b35_row6_col2" class="data row6 col2" >True</td>
#       <td id="T_92b35_row6_col3" class="data row6 col3" >True</td>
#       <td id="T_92b35_row6_col4" class="data row6 col4" >True</td>
#       <td id="T_92b35_row6_col5" class="data row6 col5" >True</td>
#     </tr>
#     <tr>
#       <th id="T_92b35_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_92b35_row7_col0" class="data row7 col0" >remove all files in the 'tmp' directory</td>
#       <td id="T_92b35_row7_col1" class="data row7 col1" >False</td>
#       <td id="T_92b35_row7_col2" class="data row7
